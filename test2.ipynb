# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('DataFile/hotel.csv')
df
# Out:
#                hotel  is_canceled  lead_time  adults  children  babies meal  \
# 0       Resort Hotel            0        342       2       0.0       0   BB
# 1       Resort Hotel            0        737       2       0.0       0   BB
# 2       Resort Hotel            0          7       1       0.0       0   BB
# 3       Resort Hotel            0         13       1       0.0       0   BB
# 4       Resort Hotel            0         14       2       0.0       0   BB
# ...              ...          ...        ...     ...       ...     ...  ...
# 119385    City Hotel            0         23       2       0.0       0   BB
# 119386    City Hotel            0        102       3       0.0       0   BB
# 119387    City Hotel            0         34       2       0.0       0   BB
# 119388    City Hotel            0        109       2       0.0       0   BB
# 119389    City Hotel            0        205       2       0.0       0   HB
#
#        deposit_type  agent  company
# ...

# %%
df.dtypes
# Out:
# hotel            object
# is_canceled       int64
# lead_time         int64
# adults            int64
# children        float64
# babies            int64
# meal             object
# deposit_type     object
# agent           float64
# company         float64
# dtype: object

# %%
dt = pd.DataFrame(df)
dt
# Out:
#                hotel  is_canceled  lead_time  adults  children  babies meal  \
# 0       Resort Hotel            0        342       2       0.0       0   BB
# 1       Resort Hotel            0        737       2       0.0       0   BB
# 2       Resort Hotel            0          7       1       0.0       0   BB
# 3       Resort Hotel            0         13       1       0.0       0   BB
# 4       Resort Hotel            0         14       2       0.0       0   BB
# ...              ...          ...        ...     ...       ...     ...  ...
# 119385    City Hotel            0         23       2       0.0       0   BB
# 119386    City Hotel            0        102       3       0.0       0   BB
# 119387    City Hotel            0         34       2       0.0       0   BB
# 119388    City Hotel            0        109       2       0.0       0   BB
# 119389    City Hotel            0        205       2       0.0       0   HB
#
#        deposit_type  agent  company
# ...

# %%
dt.dtypes
# Out:
# hotel            object
# is_canceled       int64
# lead_time         int64
# adults            int64
# children        float64
# babies            int64
# meal             object
# deposit_type     object
# agent           float64
# company         float64
# dtype: object

# %%
en_meal = pd.get_dummies(dt['meal'])
dt_en = pd.concat([dt, en_meal], axis=1)
dt_en
# Out:
#                hotel  is_canceled  lead_time  adults  children  babies meal  \
# 0       Resort Hotel            0        342       2       0.0       0   BB
# 1       Resort Hotel            0        737       2       0.0       0   BB
# 2       Resort Hotel            0          7       1       0.0       0   BB
# 3       Resort Hotel            0         13       1       0.0       0   BB
# 4       Resort Hotel            0         14       2       0.0       0   BB
# ...              ...          ...        ...     ...       ...     ...  ...
# 119385    City Hotel            0         23       2       0.0       0   BB
# 119386    City Hotel            0        102       3       0.0       0   BB
# 119387    City Hotel            0         34       2       0.0       0   BB
# 119388    City Hotel            0        109       2       0.0       0   BB
# 119389    City Hotel            0        205       2       0.0       0   HB
#
# ...

# %%
plot = dt.boxplot(column=['lead_time','adults','children','babies','agent'])
plot
# Out:
# <AxesSubplot:>
